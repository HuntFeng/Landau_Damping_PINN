# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from pinn import F
torch.set_default_dtype(torch.float64)

# %%
# epoch 9100 loss=9.246306191825073e-05
model_file = "PINN"
model = F()
model.load_state_dict(torch.load(model_file))
model.load_data("simulation/data.npz")
model.test()
